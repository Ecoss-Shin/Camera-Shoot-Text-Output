# %% [markdown]
# # 원본 컬러,흑백 이미지 저장 GUI

# %%
from tkinter import *
from PIL import ImageTk, Image # Pillow
import cv2
import datetime
import numpy as np

# GUI 설계
win = Tk() # 인스턴스 생성

win.title("Ecoss_Solution") # 제목 표시줄 추가
win.option_add("*Font", "맑은고딕 25") # 전체 폰트

#win.resizable(False, False) # x축, y축 크기 조정 비활성화

# 라벨 추가
lbl = Label(win, text="카메라 촬영 및 텍스트 출력")
lbl.grid(row=0, column=0) # 라벨 행, 열 배치

# 프레임 추가
frm = Frame(win, bg="white", width=720, height=480) # 프레임 너비, 높이 설정
frm.grid(row=1, column=0) # 격자 행, 열 배치

# 라벨 추가
lbl1 = Label(frm)
lbl1.grid()

cap = cv2.VideoCapture(1) # VideoCapture 객체 정의

def video_play():
   ret, frame = cap.read()
   frame = cv2.flip(frame, -1) # 상하반전
   frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

   img = Image.fromarray(frame)
   imgtk = ImageTk.PhotoImage(image=img)

   lbl1.imgtk = imgtk
   lbl1.configure(image=imgtk)
   lbl1.after(10, video_play)

video_play()

# 버튼 추가
btn = Button(win, text = "촬영") # 버튼 생성
btn.grid(row=2, column=0) # 라벨 행, 열 배치
btn.config(width = 5, height = 1) # 버튼 크기

def alert():
    
    ret, frame = cap.read()
    frame = cv2.flip(frame, -1) # 상하반전
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # 컬러 이미지 저장
    original_img = 'Original_img\Original_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    original_img_gray = 'Original_img\Original_gray_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    
    cv2.imwrite(original_img, frame)
    cv2.imwrite(original_img_gray, gray)

btn.config(command = alert) # 버튼 기능

win.mainloop() #GUI 시작

# %% [markdown]
# # 이미지 자르기 컬러, 흑백 이미지 저장

# %%
from tkinter import *
from PIL import ImageTk, Image # Pillow
import cv2
import datetime
import numpy as np
import pytesseract

# GUI 설계
win = Tk() # 인스턴스 생성

win.title("Ecoss_Solution") # 제목 표시줄 추가
win.option_add("*Font", "맑은고딕 25") # 전체 폰트

#win.resizable(False, False) # x축, y축 크기 조정 비활성화

# 라벨 추가
lbl = Label(win, text="카메라 촬영 및 텍스트 출력")
lbl.grid(row=0, column=0) # 라벨 행, 열 배치

# 프레임 추가
frm = Frame(win, bg="white", width=720, height=480) # 프레임 너비, 높이 설정
frm.grid(row=1, column=0) # 격자 행, 열 배치

# 라벨 추가
lbl1 = Label(frm)
lbl1.grid()

cap = cv2.VideoCapture(1) # VideoCapture 객체 정의

def video_play():
   ret, frame = cap.read()
   frame = cv2.flip(frame, -1) # 상하반전
   frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

   img = Image.fromarray(frame)
   imgtk = ImageTk.PhotoImage(image=img)

   lbl1.imgtk = imgtk
   lbl1.configure(image=imgtk)
   lbl1.after(10, video_play)

video_play()

# 버튼 추가
btn = Button(win, text = "촬영") # 버튼 생성
btn.grid(row=2, column=0) # 라벨 행, 열 배치
btn.config(width = 5, height = 1) # 버튼 크기

def alert():
    
    ret, frame = cap.read()
    frame = cv2.flip(frame, -1) # 상하반전
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # 오리지날 컬러 이미지 저장
    original_img = 'Original_img\Original_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    original_img_gray = 'Original_img\Original_gray_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    
    cv2.imwrite(original_img, frame)
    cv2.imwrite(original_img_gray, gray)
    
    # 편짐된 이미지 저장
    img = cv2.imread(original_img)
    img1 = cv2.imread(original_img_gray)
    
    img = img[100:450, 30:610].copy()
    img1 = img1[100:450, 30:610].copy()
    
    Cut_img = 'Cut_img\Cut_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    Cut_img_gray = 'Cut_img\Cut_gray_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    
    cv2.imwrite(Cut_img, img)
    cv2.imwrite(Cut_img_gray, img1)


btn.config(command = alert) # 버튼 기능

win.mainloop() #GUI 시작

# %% [markdown]
# # 저장된 이미지 텍스트 출력

# %%
from tkinter import *
from PIL import ImageTk, Image # Pillow
import cv2
import datetime
import numpy as np
import pytesseract

# GUI 설계
win = Tk() # 인스턴스 생성

win.title("Ecoss_Solution") # 제목 표시줄 추가
win.option_add("*Font", "맑은고딕 25") # 전체 폰트

#win.resizable(False, False) # x축, y축 크기 조정 비활성화

# 라벨 추가
lbl = Label(win, text="카메라 촬영 및 텍스트 출력")
lbl.grid(row=0, column=0) # 라벨 행, 열 배치

# 프레임 추가
frm = Frame(win, bg="white", width=720, height=480) # 프레임 너비, 높이 설정
frm.grid(row=1, column=0) # 격자 행, 열 배치

# 라벨 추가
lbl1 = Label(frm)
lbl1.grid()

cap = cv2.VideoCapture(1) # VideoCapture 객체 정의

def video_play():
   ret, frame = cap.read()
   frame = cv2.flip(frame, -1) # 상하반전
   frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

   img = Image.fromarray(frame)
   imgtk = ImageTk.PhotoImage(image=img)

   lbl1.imgtk = imgtk
   lbl1.configure(image=imgtk)
   lbl1.after(10, video_play)

video_play()

# 버튼 추가
btn = Button(win, text = "촬영") # 버튼 생성
btn.grid(row=2, column=0) # 라벨 행, 열 배치
btn.config(width = 5, height = 1) # 버튼 크기

def alert():
    
    ret, frame = cap.read()
    frame = cv2.flip(frame, -1) # 상하반전
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # 오리지날 컬러 이미지 저장
    original_img = 'Original_img\Original_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    original_img_gray = 'Original_img\Original_gray_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    
    cv2.imwrite(original_img, frame)
    cv2.imwrite(original_img_gray, gray)
    
    # 편짐된 이미지 저장
    img = cv2.imread(original_img)
    img1 = cv2.imread(original_img_gray)
    
    img = img[100:450, 30:610].copy()
    img1 = img1[100:450, 30:610].copy()
    
    Cut_img = 'Cut_img\Cut_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    Cut_img_gray = 'Cut_img\Cut_gray_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    
    cv2.imwrite(Cut_img, img)
    cv2.imwrite(Cut_img_gray, img1)
    
    pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
    text = pytesseract.image_to_string(img1, lang = "kor+eng")

    print(text)

btn.config(command = alert) # 버튼 기능

win.mainloop() #GUI 시작
# Out:
# 박 현 민 Hyeonmin Park
#
# 인 턴 사 원 ㆍ 인 재 개 발 원 첨 단 기 술 연 수 소
# Intern
#
# Samsung Advanced Technology Training Institute
# Samsung Electronics Leadership Center

# %% [markdown]
# # 화질이 좋지 않을때 이미지 선명하게 하고 텍스트 출력

# %%
from tkinter import *
from PIL import ImageTk, Image # Pillow
import cv2
import datetime
import numpy as np
import pytesseract

# GUI 설계
win = Tk() # 인스턴스 생성

win.title("Ecoss_Solution") # 제목 표시줄 추가
win.option_add("*Font", "맑은고딕 25") # 전체 폰트

#win.resizable(False, False) # x축, y축 크기 조정 비활성화

# 라벨 추가
lbl = Label(win, text="카메라 촬영 및 텍스트 출력")
lbl.grid(row=0, column=0) # 라벨 행, 열 배치

# 프레임 추가
frm = Frame(win, bg="white", width=720, height=480) # 프레임 너비, 높이 설정
frm.grid(row=1, column=0) # 격자 행, 열 배치

# 라벨 추가
lbl1 = Label(frm)
lbl1.grid()

cap = cv2.VideoCapture(1) # VideoCapture 객체 정의

def video_play():
   ret, frame = cap.read()
   frame = cv2.flip(frame, -1) # 상하반전
   frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

   img = Image.fromarray(frame)
   imgtk = ImageTk.PhotoImage(image=img)

   lbl1.imgtk = imgtk
   lbl1.configure(image=imgtk)
   lbl1.after(10, video_play)

video_play()

# 버튼 추가
btn = Button(win, text = "촬영") # 버튼 생성
btn.grid(row=2, column=0) # 라벨 행, 열 배치
btn.config(width = 5, height = 1) # 버튼 크기

def alert():
    
    ret, frame = cap.read()
    frame = cv2.flip(frame, -1) # 상하반전
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # 오리지날 컬러 이미지 저장
    original_img = 'Original_img\Original_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    original_img_gray = 'Original_img\Original_gray_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    
    cv2.imwrite(original_img, frame)
    cv2.imwrite(original_img_gray, gray)
    
    # 편짐된 이미지 저장
    img = cv2.imread(original_img)
    img1 = cv2.imread(original_img_gray)
    
    img = img[100:450, 30:610].copy()
    img1 = img1[100:450, 30:610].copy()
    
    Cut_img = 'Cut_img\Cut_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    Cut_img_gray = 'Cut_img\Cut_gray_' + datetime.datetime.now().strftime("%Y%m%d_%H%M%S") + '.jpg'
    
    cv2.imwrite(Cut_img, img)
    cv2.imwrite(Cut_img_gray, img1)
    
    # 이미지 선명하게 하기
    kernel = np.array([[0, -1, 0],
                      [-1, 5, -1],
                      [0, -1, 0]])
    
    #kernel = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])

    # 커널 적용 
    image_sharp = cv2.filter2D(img1, -1, kernel)
    
    cv2.imwrite('image.jpg', image_sharp)
    
    pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
    text = pytesseract.image_to_string(image_sharp, lang = "kor+eng")

    print(text)


btn.config(command = alert) # 버튼 기능

win.mainloop() #GUI 시작
# Out:
# 박 현 민 Hyeonmin Park
#
# 인 턴 사 원 - 인 재 개 발 원 점 단 기 술 연 수 소
# Intern
#
# Samsung Advanced Technology Training Institute:
# Samsung Electronics Leadership Center
